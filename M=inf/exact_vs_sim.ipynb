# %%
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (14, 7)

# %%
plt.plot(np.arange(0, 50.01, 0.01), np.load("f(T=500,delta_t=0.01).npy"))
plt.ylabel("MAE")
plt.xlabel("time")
# Out:
# Text(0.5, 0, 'time')
